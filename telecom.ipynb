# %%
import pandas as pd
from scipy import stats

# 1. Load the dataset
df = pd.read_csv('telecom-data-set.csv')

# 2. Create a Contingency Table for Payment Method vs Customer Churn
contingency_table = pd.crosstab(df['PaymentMethod'], df['Churn'])
print("--- Contingency Table ---")
print(contingency_table)
print("\n-------------------------\n")

# 3. Perform the Chi-Square Test of Independence
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p}")

# 4. Interpret the results based on Alpha level (0.05)
if p < 0.05:
    print("\nResult: There is a statistically significant relationship between Payment Method and Customer Churn! (We reject the Null Hypothesis)")
else:
    print("\nResult: There is no significant relationship between Payment Method and Customer Churn.")
# Out:
# --- Contingency Table ---
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308
#
# -------------------------
#
# Chi-Square Statistic: 648.1423274814
# P-Value: 3.6823546520097993e-140
#
# Result: There is a statistically significant relationship between Payment Method and Customer Churn! (We reject the Null Hypothesis)

# %%
import numpy as np

# Churn rate per payment method
rate = pd.crosstab(df['PaymentMethod'], df['Churn'], normalize='index')['Yes'] * 100
print(rate.round(2))
print("Overall churn rate:", round((df['Churn'] == 'Yes').mean() * 100, 2))

# Extra statistics
print("\nDegrees of freedom:", dof)
n = contingency_table.values.sum()
k = min(contingency_table.shape) - 1
print("Cramér's V:", round(np.sqrt(chi2 / (n * k)), 3))
print("Minimum expected count:", expected.min().round(1))  # must be > 5 for the test to be valid
# Out:
# PaymentMethod
# Bank transfer (automatic)    16.71
# Credit card (automatic)      15.24
# Electronic check             45.29
# Mailed check                 19.11
# Name: Yes, dtype: float64
# Overall churn rate: 26.54
#
# Degrees of freedom: 3
# Cramér's V: 0.303
# Minimum expected count: 403.9
